# %% [markdown]
# ## Name of Students:
# ### Noam Sitbon 332391820
# ### Yedidia Friedheim 313475808

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv'
vacc_df = pd.read_csv(url)

# %% [markdown]
# Solution to question 1:

# %%
vacc_df.head() #print the first 5 rows of dataframe
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %% [markdown]
# Solution question 2: (We choose Norway because it begins with "N" like Noam)

# %%
my_country=vacc_df[vacc_df['location'].str.contains("Norway")]
my_country  #print data of Nowrway ("N" like Noam)
# Out:
#      location iso_code        date  total_vaccinations  people_vaccinated  \
# 5876   Norway      NOR  2020-12-27                 5.0                5.0
# 5877   Norway      NOR  2020-12-28               608.0              608.0
# 5878   Norway      NOR  2020-12-29              1675.0             1675.0
# 5879   Norway      NOR  2020-12-30              2102.0             2102.0
# 5880   Norway      NOR  2020-12-31              2174.0             2174.0
# ...       ...      ...         ...                 ...                ...
# 5958   Norway      NOR  2021-03-19            768922.0           505976.0
# 5959   Norway      NOR  2021-03-20            769395.0           506429.0
# 5960   Norway      NOR  2021-03-21            769650.0           506616.0
# 5961   Norway      NOR  2021-03-22            771223.0           508119.0
# 5962   Norway      NOR  2021-03-23            783851.0           520067.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %% [markdown]
# Solution question 3:

# %%
print("Number of rows is: ",len(my_country)) #print the numbers of rows in the country
# Out:
# Number of rows is:  87

# %% [markdown]
# Solution question 4:

# %%
max_vacc = my_country.daily_vaccinations.max()
my_country.loc[my_country.daily_vaccinations==max_vacc,["date"]]
#print the date that has the most daily vaccinations
# Out:
#             date
# 5949  2021-03-10

# %% [markdown]
# Solution question 5

# %%
a=my_country.iloc[0:3]
a[["location","date","daily_vaccinations"]]
#print the first 3 rows and "location","date","daily_vaccinations" columns of Norway
# Out:
#      location        date  daily_vaccinations
# 5876   Norway  2020-12-27                 NaN
# 5877   Norway  2020-12-28               603.0
# 5878   Norway  2020-12-29               835.0

# %% [markdown]
# Solution question 6

# %%
print("The mean of daily vaccinations is: ",my_country.daily_vaccinations.mean())
#calculate the daily mean vaccinations
# Out:
# The mean of daily vaccinations is:  8932.441860465116

# %% [markdown]
# Solution question 7

# %%
my_country_without_Nan=my_country.dropna(subset=["people_vaccinated_per_hundred"])
my_country_without_Nan #print the data without NaN in "people_vaccinated_per_hundred"'s column
# Out:
#      location iso_code        date  total_vaccinations  people_vaccinated  \
# 5876   Norway      NOR  2020-12-27                 5.0                5.0
# 5877   Norway      NOR  2020-12-28               608.0              608.0
# 5878   Norway      NOR  2020-12-29              1675.0             1675.0
# 5879   Norway      NOR  2020-12-30              2102.0             2102.0
# 5880   Norway      NOR  2020-12-31              2174.0             2174.0
# ...       ...      ...         ...                 ...                ...
# 5958   Norway      NOR  2021-03-19            768922.0           505976.0
# 5959   Norway      NOR  2021-03-20            769395.0           506429.0
# 5960   Norway      NOR  2021-03-21            769650.0           506616.0
# 5961   Norway      NOR  2021-03-22            771223.0           508119.0
# 5962   Norway      NOR  2021-03-23            783851.0           520067.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
from statistics import *

# %% [markdown]
# Solution question 8:

# %%
index_0=my_country_without_Nan[my_country_without_Nan["people_vaccinated_per_hundred"]==0.00].index #find index of all val equal to 0
my_country_without_Nan.drop(index_0, inplace=True) #remove the 0
print("The harmonic mean is: ",harmonic_mean(my_country_without_Nan["people_vaccinated_per_hundred"])) #calculate harmonic mean of "people_vaccinated_per_hundred"
# Out:
# The harmonic mean is:  0.25587879172254613

# %% [markdown]
# Solution question 9:

# %%
print("The median mean is: ",my_country_without_Nan["daily_vaccinations"].median()) #calculate median mean
# Out:
# The median mean is:  9734.0

# %%
print("The mean is: ",my_country_without_Nan["daily_vaccinations"].mean()) #calculate traditional mean
# Out:
# The mean is:  8932.441860465116

# %% [markdown]
# From line 32 and33 we can see that the median mean is bigger than the traditional mean.
